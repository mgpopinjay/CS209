# %% [markdown]
# # Homework 1. Exploratory Data Analysis
#
# Due: Thursday, September 18, 2014 11:59 PM
#
# <a href=https://github.com/cs109/2014/blob/master/homework/HW1.ipynb download=HW1.ipynb> Download this assignment</a>
#
# ---

# %% [markdown]
# ## Introduction
#
# In this homework we ask you three questions that we expect you to answer using data. For each question we ask you to complete a series of tasks that should help guide you through the data analysis. Complete these tasks and then write a short (100 words or less) answer to the question.
#
# **Note**: We will briefly discuss this homework assignment on Thursday in class.
#
# #### Data
# For this assignment we will use two databases:
#
# 1. The [Sean Lahman's Baseball Database](http://seanlahman.com/baseball-archive/statistics) which contains the "complete batting and pitching statistics from 1871 to 2013, plus fielding statistics, standings, team stats, managerial records, post-season data, and more. For more details on the latest release, please [read the documentation](http://seanlahman.com/files/database/readme2012.txt)."
#
# 2. [Gapminder](http://www.gapminder.org) is a great resource that contains over [500 data sets](http://www.gapminder.org/data/) related to world indicators such as income, GDP and life expectancy.
#
#
# #### Purpose
#
# In this assignment, you will learn how to:
#
# a. Load in CSV files from the web.
#
# b. Create functions in python.
#
# C. Create plots and summary statistics for exploratory data analysis such as histograms, boxplots and scatter plots.
#
#
# #### Useful libraries for this assignment
#
# * [numpy](http://docs.scipy.org/doc/numpy-dev/user/index.html), for arrays
# * [pandas](http://pandas.pydata.org/), for data frames
# * [matplotlib](http://matplotlib.org/), for plotting
#
# ---

# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.axes_style()

# %% [markdown]
# ## Problem 1
#
# In Lecture 1, we showed a plot that provided evidence that the 2002 and 2003 Oakland A's, a team that used data science, had a competitive advantage. Since, others teams have started using data science as well. Use exploratory data analysis to determine if the competitive advantage has since disappeared.

# %% [markdown]
# #### Problem 1(a)
# Load in [these CSV files](http://seanlahman.com/files/database/lahman-csv_2014-02-14.zip) from the [Sean Lahman's Baseball Database](http://seanlahman.com/baseball-archive/statistics). For this assignment, we will use the 'Salaries.csv' and 'Teams.csv' tables. Read these tables into a pandas `DataFrame` and show the head of each table.
#
# **Hint** Use the [requests](http://docs.python-requests.org/en/latest/), [StringIO](http://docs.python.org/2/library/stringio.html) and [zipfile](https://docs.python.org/2/library/zipfile.html) modules to get from the web.

# %%
import zipfile
import requests
import StringIO

#request file package from source URL
r = requests.get('http://seanlahman.com/files/database/lahman-csv_2014-02-14.zip')

# %%
f = StringIO.StringIO(r.content)
z = zipfile.ZipFile(f)
print z.namelist()
# Out:
# ['SchoolsPlayers.csv', 'SeriesPost.csv', 'Teams.csv', 'TeamsFranchises.csv', 'TeamsHalf.csv', 'AllstarFull.csv', 'Appearances.csv', 'AwardsManagers.csv', 'AwardsPlayers.csv', 'AwardsShareManagers.csv', 'AwardsSharePlayers.csv', 'Batting.csv', 'BattingPost.csv', 'Fielding.csv', 'FieldingOF.csv', 'FieldingPost.csv', 'HallOfFame.csv', 'Managers.csv', 'ManagersHalf.csv', 'Master.csv', 'Pitching.csv', 'PitchingPost.csv', 'readme2013.txt', 'Salaries.csv', 'Schools.csv']

# %%
team = pd.read_csv(z.open('Teams.csv'))
print team.head()
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L ...  DP    FP  \
# 0    1871  NaN    PH1      PNA   NaN     1  28    NaN  21   7 ... NaN  0.84
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9 ... NaN  0.82
# 2    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10 ... NaN  0.83
# 3    1871  NaN    WS3      OLY   NaN     4  32    NaN  15  15 ... NaN  0.85
# 4    1871  NaN    NY2      NNA   NaN     5  33    NaN  16  17 ... NaN  0.83
#
#                       name                      park  attendance  BPF  PPF  \
# 0   Philadelphia Athletics  Jefferson Street Grounds         NaN  102   98
# 1  Chicago White Stockings   Union Base-Ball Grounds         NaN  104  102
# 2     Boston Red Stockings       South End Grounds I         NaN  103   98
# 3      Washington Olympics          Olympics Grounds         NaN   94   98
# 4         New York Mutuals  Union Grounds (Brooklyn)         NaN   90   88
#
#    teamIDBR  teamIDlahman45  teamIDretro
# 0       ATH             PH1          PH1
# 1       CHI             CH1          CH1
# 2       BOS             BS1          BS1
# 3       OLY             WS3          WS3
# 4       NYU             NY2          NY2
#
# [5 rows x 48 columns]

# %%
salary = pd.read_csv(z.open('Salaries.csv'))
print salary.head()
# Out:
#    yearID teamID lgID   playerID   salary
# 0    1985    BAL   AL  murraed02  1472819
# 1    1985    BAL   AL   lynnfr01  1090000
# 2    1985    BAL   AL  ripkeca01   800000
# 3    1985    BAL   AL   lacyle01   725000
# 4    1985    BAL   AL  flanami01   641667

# %% [markdown]
# #### Problem 1(b)
#
# Summarize the Salaries DataFrame to show the total salaries for each team for each year. Show the head of the new summarized DataFrame.

# %%
salary = salary.groupby(['teamID', 'yearID']).sum()
print salary
# Out:
#                   salary
# teamID yearID
# ANA    1997     31135472
#        1998     41281000
#        1999     55388166
#        2000     51464167
#        2001     47535167
#        2002     61721667
#        2003     79031667
#        2004    100534667
# ARI    1998     32347000
#        1999     68703999
#        2000     81027833
#        2001     85082999
#        2002    102819999
#        2003     80657000
#        2004     69780750
#        2005     62329166
#        2006     59684226
#        2007     52067546
#        2008     66202712
#        2009     73115666
#        2010     60718166
#        2011     53639833
#        2012     73804833
#        2013     90132000
# ATL    1985     14807000
#        1986     17102786
#        1987     16544560
#        1988     12728174
#        1989     11112334
#        1990     14555501
# ...                  ...
# TOR    1993     47279166
#        1994     43433668
#        1995     50590000
#        1996     29555083
#        1997     47079833
#        1998     51376000
#        1999     45444333
#        2000     44838332
#        2001     76895999
#        2002     76864333
#        2003     51269000
#        2004     50017000
#        2005     45719500
#        2006     71365000
#        2007     81942800
#        2008     97793900
#        2009     80538300
#        2010     62234000
#        2011     62567800
#        2012     75009200
#        2013    126288100
# WAS    2005     48581500
#        2006     63143000
#        2007     36947500
#        2008     54961000
#        2009     59928000
#        2010     61400000
#        2011     63856928
#        2012     80855143
#        2013    113703270
#
# [828 rows x 1 columns]

# %% [markdown]
# #### Problem 1(c)
#
# Merge the new summarized Salaries DataFrame and Teams DataFrame together to create a new DataFrame
# showing wins and total salaries for each team for each year year. Show the head of the new merged DataFrame.
#
# **Hint**: Merge the DataFrames using `teamID` and `yearID`.

# %%
wins = team[['teamID', 'yearID', 'W']]
wins = wins.groupby(["teamID", "yearID"]).sum()
print wins.head()
# Out:
#                 W
# teamID yearID
# ALT    1884     6
# ANA    1997    84
#        1998    85
#        1999    70
#        2000    82

# %%
#salary_wins = pd.merge(salary, wins, left_on='teamID', right_on='teamID')
#salary_wins = pd.merge(salary, wins, left_index=True, right_index=True, how='inner')
#print salary_wins

salary_wins = pd.merge(wins.reset_index(), salary.reset_index(), on=['teamID', 'yearID'], how='inner')
print salary_wins.head()
# Out:
#   teamID  yearID   W    salary
# 0    ANA    1997  84  31135472
# 1    ANA    1998  85  41281000
# 2    ANA    1999  70  55388166
# 3    ANA    2000  82  51464167
# 4    ANA    2001  75  47535167

# %% [markdown]
# #### Problem 1(d)
#
# How would you graphically display the relationship between total wins and total salaries for a given year? What kind of plot would be best? Choose a plot to show this relationship and specifically annotate the Oakland baseball team on the on the plot. Show this plot across multiple years. In which years can you detect a competitive advantage from the Oakland baseball team of using data science? When did this end?
#
# **Hints**: Use a `for` loop to consider multiple years. Use the `teamID` (three letter representation of the team name) to save space on the plot.

# %%
#print salary_wins[:5]

for year, df in salary_wins.groupby('yearID'):
    x = df['salary']
    y = df['W']
    #label = df['teamID'] 
    plt.scatter(x, y, color = 'black', alpha = .5)
    #if label == 'OAK':
        #plt.annotate(label, xy=(x,y), xytext=(3, 1.5));
    plt.xlabel('Salaries in Hundred Millions')
    plt.ylabel('Wins')
    plt.title(year)
    plt.show()

# %% [markdown]
# #### Problem 1(e):
#
# **For AC209 Students**: Fit a linear regression to the data from each year and obtain the residuals. Plot the residuals against time to detect patterns that support your answer in 1(d).

# %%
for year, df in salary_wins.groupby('yearID'):
    x = df['salary']
    y = df['W']
    sns.lmplot('salary', 'W', df)
    plt.show()
    sns.residplot('salary', 'W', df)
    plt.show()

# %% [markdown]
# ## Discussion for Problem 1
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---

# %% [markdown]
# ## Problem 2
#
# Several media reports have demonstrated the income inequality has increased in the US during this last decade. Here we will look at global data. Use exploratory data analysis to determine if the gap between Africa/Latin America/Asia and Europe/NorthAmerica has increased, decreased or stayed the same during the last two decades.

# %% [markdown]
# #### Problem 2(a)
#
# Using the list of countries by continent from [World Atlas](http://www.worldatlas.com/cntycont.htm) data, load in the `countries.csv` file into a pandas DataFrame and name this data set as `countries`.  This data set can be found on Github in the 2014_data repository [here](https://github.com/cs109/2014_data/blob/master/countries.csv).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
 
countries = pd.read_csv('https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv')
print countries.head()

# %% [markdown]
# Using the [data available on Gapminder](http://www.gapminder.org/data/), load in the [Income per person (GDP/capita, PPP$ inflation-adjusted)](https://spreadsheets.google.com/pub?key=phAwcNAVuyj1jiMAkmq1iMg&gid=0) as a pandas DataFrame and name this data set as `income`.
#
# **Hint**: Consider using the pandas function `pandas.read_excel()` to read in the .xlsx file directly.

# %%
import pandas as pd
income = pd.read_csv('https://spreadsheets.google.com/pub?key=phAwcNAVuyj1jiMAkmq1iMg&gid=0&output=csv')
income.head()
# Out:
#              gdp pc test        1800        1801        1802        1803  \
# 0               Abkhazia         NaN         NaN         NaN         NaN
# 1            Afghanistan  472.053500  472.053500  472.053500  472.053500
# 2  Akrotiri and Dhekelia         NaN         NaN         NaN         NaN
# 3                Albania  601.215222  601.839631  602.464688  603.090394
# 4                Algeria  766.253664  766.234779  766.215895  766.197011
#
#          1804        1805        1806        1807        1808     ...      \
# 0         NaN         NaN         NaN         NaN         NaN     ...
# 1  472.053500  472.053500  472.053500  472.053500  472.053500     ...
# 2         NaN         NaN         NaN         NaN         NaN     ...
# 3  603.716751  604.343757  604.971415  605.599725  606.228687     ...
# 4  766.178127  766.159244  766.140362  766.121480  766.102598     ...
#
#           2003         2004  2005         2006         2007         2008  \
# 0          NaN          NaN   NaN          NaN          NaN          NaN
# 1   785.127571   804.717458   874   887.914578   983.652314   984.805841
# 2          NaN          NaN   NaN          NaN          NaN          NaN
# 3  4855.210024  5115.252837  5369  5652.049321  5958.021197  6365.530359
# 4  5576.851564  5790.967692  6011  6022.270940  6133.782763  6162.719840
#
#           2009         2010         2011         2012
# 0          NaN          NaN          NaN          NaN
# 1  1154.859365  1214.613653  1261.354184  1349.696941
# 2          NaN          NaN          NaN          NaN
# 3  6550.896164  6746.445312  6914.267317  6969.306283
# 4  6173.729741  6300.648214  6354.640523  6419.127829
#
# [5 rows x 214 columns]

# %% [markdown]
# Transform the data set to have years as the rows and countries as the columns. Show the head of this data set when it is loaded.

# %%
print income.T.head()
# Out:
#                   0            1                      2         3         4    \
# gdp pc test  Abkhazia  Afghanistan  Akrotiri and Dhekelia   Albania   Algeria
# 1800              NaN     472.0535                    NaN  601.2152  766.2537
# 1801              NaN     472.0535                    NaN  601.8396  766.2348
# 1802              NaN     472.0535                    NaN  602.4647  766.2159
# 1803              NaN     472.0535                    NaN  603.0904   766.197
#
#                         5         6         7         8    \
# gdp pc test  American Samoa   Andorra    Angola  Anguilla
# 1800               674.4537  1260.123  359.9326  775.6687
# 1801               674.4537  1262.214  359.9326  775.6687
# 1802               674.4537  1264.309  359.9326  775.6687
# 1803               674.4537  1266.407  359.9326  775.6687
#
#                              9           ...                      250  \
# gdp pc test  Antigua and Barbuda         ...           Western Sahara
# 1800                    538.3762         ...                      NaN
# 1801                    538.3762         ...                      NaN
# 1802                    538.3762         ...                      NaN
# 1803                    538.3762         ...                      NaN
#
#                  251                    252                           253  \
# gdp pc test  Vietnam  Virgin Islands (U.S.)  Yemen Arab Republic (Former)
# 1800         459.709                    NaN                           NaN
# 1801         459.709                    NaN                           NaN
# 1802         459.709                    NaN                           NaN
# 1803         459.709                    NaN                           NaN
#
#                                    254          255         256       257  \
# gdp pc test  Yemen Democratic (Former)  Yemen, Rep.  Yugoslavia    Zambia
# 1800                               NaN     661.9024         NaN  364.4648
# 1801                               NaN     662.0586         NaN  364.4648
# 1802                               NaN     662.2148         NaN  364.4648
# 1803                               NaN      662.371         NaN  364.4648
#
#                   258    259
# gdp pc test  Zimbabwe  Åland
# 1800         372.8183    NaN
# 1801         372.8183    NaN
# 1802         372.8183    NaN
# 1803         372.8183    NaN
#
# [5 rows x 260 columns]

# %% [markdown]
# #### Problem 2(b)
#
# Graphically display the distribution of income per person across all countries in the world for any given year (e.g. 2000).  What kind of plot would be best?

# %%
import matplotlib.pyplot as plt
income_renamed = income.rename(columns={'gdp pc test':'Country'}, inplace=False)

#merge 2 df by country column
country_income = pd.merge(countries, income_renamed, on=['Country', 'Country'])

#isolate income to 1 year
merged2000 = country_income[['Country', 'Region', '2000']]

#remove NaN's
merged2000cleaned= merged2000.dropna()

#set bin number, color and fig size 
merged2000cleaned['2000'].hist(bins=60, color = 'pink', figsize=(12,4))
plt.title('Global Income Distribution in 2000')
plt.xlabel('GDP')
plt.ylabel('Number of Countries')

# %% [markdown]
# #### Problem 2(c)
#
# Write a function to merge the `countries` and `income` data sets for any given year.

# %%
def income_year(year):   #setup year as input argument
    print country_income[['Country', year]];   #pass in year to callout columns
income_year(year='2003')
# Out:
#                               Country          2003
# 0                             Algeria   5576.851564
# 1                              Angola   2785.393957
# 2                               Benin   1386.048537
# 3                            Botswana  11391.086540
# 4                             Burundi    427.140638
# 5                            Cameroon   1967.394950
# 6                          Cape Verde   2600.552094
# 7                                Chad   1287.084562
# 8                             Comoros   1070.954933
# 9                            Djibouti   1931.595841
# 10                              Egypt   4814.390355
# 11                  Equatorial Guinea   8913.559630
# 12                            Eritrea    713.581696
# 13                           Ethiopia    498.418495
# 14                              Gabon  12610.072607
# 15                             Gambia    683.541357
# 16                              Ghana   1143.694644
# 17                             Guinea    934.371361
# 18                      Guinea-Bissau    560.944594
# 19                              Kenya   1291.423304
# 20                            Lesotho   1311.243045
# 21                            Liberia    365.828636
# 22                              Libya   9954.114323
# 23                         Madagascar    953.053654
# 24                             Malawi    674.880907
# 25                               Mali    994.711129
# 26                         Mauritania   1619.466002
# 27                          Mauritius   9564.700618
# 28                            Morocco   3400.374427
# 29                         Mozambique    671.773746
# ..                                ...           ...
# 147             Saint Kitts and Nevis  12443.507364
# 148                       Saint Lucia   8530.069554
# 149  Saint Vincent and the Grenadines   6267.195079
# 150               Trinidad and Tobago  13030.451850
# 151                     United States  40044.184580
# 152                         Australia  31634.242428
# 153                              Fiji   4019.140800
# 154                          Kiribati   3503.395986
# 155                  Marshall Islands   6016.831189
# 156                             Nauru   6961.018637
# 157                       New Zealand  23728.482898
# 158                             Palau  11888.324910
# 159                  Papua New Guinea   1722.485131
# 160                             Samoa   4545.090009
# 161                   Solomon Islands   1587.568642
# 162                             Tonga   5228.760684
# 163                            Tuvalu   4643.911655
# 164                           Vanuatu   3251.043515
# 165                         Argentina   9481.372262
# 166                           Bolivia   3450.756099
# 167                            Brazil   8110.411789
# 168                             Chile  11082.553010
# 169                          Colombia   5885.519660
# 170                           Ecuador   5910.998347
# 171                            Guyana   3198.595034
# 172                          Paraguay   3828.383762
# 173                              Peru   6054.905034
# 174                          Suriname   6446.036724
# 175                           Uruguay   7853.818686
# 176                         Venezuela   7810.970816
#
# [177 rows x 2 columns]

# %% [markdown]
# #### Problem 2(d)
#
# Use exploratory data analysis tools such as histograms and boxplots to explore the distribution of the income per person by region data set from 2(c) for a given year. Describe how these change through the recent years?
#
# **Hint**: Use a `for` loop to consider multiple years.

# %%
import matplotlib.pyplot as pltdef

for yr in [1800,1850, 1900, 1950, 2000, 2012]:   #define which years to plot
    yr = str(yr)   #convert the year to string for passing into the data frame to call out year column headers 
    country_income.boxplot(yr, by = 'Region')  #plot by year defined in the for loop

# %% [markdown]
# ## Discussion for Problem 2
#
# 2B.  Histogram represents the income distribution across nicely because it provides comparioson of the number of countries that fall into different GDP ranges. For instance, it shows while a number of countries with GDPs above $40k, most country are still below $15k in GDP.
# 2D.  Between year 2000 and 2012, Asia's highest GDP exceeded that of Europe
#
# ---

# %% [markdown]
# ## Problem 3
#
# In general, if group A has larger values than group B on average, does this mean the largest values are from group A? Discuss after completing each of the problems below.

# %% [markdown]
# #### Problem 3(a)
#
# Assume you have two list of numbers, X and Y, with distribution approximately normal. X and Y have standard deviation equal to 1, but the average of X is different from the average of Y.  If the difference in the average of X and the average of Y is larger than 0, how does the proportion of X > a compare to the proportion of Y > a?

# %% [markdown]
# Write a function that analytically calculates the ratio of these two proportions: Pr(X > a)/Pr(Y > a) as function of the difference in the average of X and the average of Y.
#
# **Hint**: Use the `scipy.stats` module for useful functions related to a normal random variable such as the probability density function, cumulative distribution function and survival function.
#
# **Update**: Assume Y is normally distributed with mean equal to 0.

# %%
"""
Function
--------
ratioNormals

Return ratio of these two proportions: 
    Pr(X > a)/Pr(Y > a) as function of 
    the difference in the average of X 
    and the average of Y. 

Parameters
----------
diff : difference in the average of X 
    and the average of Y. 
a : cutoff value

Returns
-------
Returns ratio of these two proportions: 
    Pr(X > a)/Pr(Y > a)
    
Example
-------
>>> ratioNormals(diff = 1, a = 2)
"""
import scipy as sp
import numpy as np

#print sp.stats.norm.rvs(loc=3, size=10)

stddev = 1
def ratioNormals(diff, a):
    ratio = (1-sp.stats.norm(diff, stddev).cdf(a))/(1-sp.stats.norm(mean_y, stddev).cdf(a))
    return ratio

ratioNormals(diff = 1, a = 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-808-6742ac5788c5> in <module>()
#      34     return ratio
#      35
# ---> 36 ratioNormals(diff = 1, a = 2)
#
# <ipython-input-808-6742ac5788c5> in ratioNormals(diff, a)
#      31 stddev = 1
#      32 def ratioNormals(diff, a):
# ---> 33     ratio = (1-sp.stats.norm(diff, stddev).cdf(a))/(1-sp.stats.norm(mean_y, stddev).cdf(a))
#      34     return ratio
#      35
#
# NameError: global name 'mean_y' is not defined

# %% [markdown]
# Show the curve for different values of a (a = 2,3,4 and 5).

# %%
from scipy.stats import *

def ratioNormals(diff, a):
    pr_x = norm.sf(a, loc=0, scale=1) 
    pr_y = norm.sf(a, loc=diff, scale=1) 
    
    return (1-pr_x)/(1-pr_y)

np.linspace(0, 10, num=4)
test_values = [2, 3, 4, 5]
x_vals = np.linspace(0, 3, num=10)

for val in test_values:
    y_vals = [ratioNormals(x, val) for x in x_vals]
    plt.plot(x_vals, y_vals)
    plt.text(x_vals[-1], y_vals[-1], 'a = %s' %str(val), size = 12)
    plt.ylabel('Ratio')
    plt.xlabel("Difference 'a'")

# %% [markdown]
# #### Problem 3(b)
#
# Now consider the distribution of income per person from two regions: Asia and South America. Estimate the average income per person across the countries in those two regions. Which region has the larger average of income per person across the countries in that region?
#
# **Update**: Use the year 2012.

# %%
#isolate 2012 income data
merged2012 = country_income[['Country', 'Region','2012']]

#sort by region and calculate avg income
region2012 = merged2012.groupby('Region').mean().astype('int')
print region2012
# Out:
#                 2012
# Region
# AFRICA          3673
# ASIA           14510
# EUROPE         22744
# NORTH AMERICA  12543
# OCEANIA         9330
# SOUTH AMERICA   9471

# %% [markdown]
# #### Problem 3(c)
#
# Calculate the proportion of countries with income per person that is greater than 10,000 dollars. Which region has a larger proportion of countries with income per person greater than 10,000 dollars? If the answer here is different from the answer in 3(b), explain why in light of your answer to 3(a).
#
# **Update**: Use the year 2012.

# %%
#isolate rows with GDP > 10k
above10k = merged2012[(merged2012['2012'] > 10000)]

#count the number of region with >10k GDP
#count_above10k = above10k['Region'].value_counts()
count_above10k = above10k.groupby('Region').agg('count')
print count_above10k
count_country = merged2012.groupby('Region').agg('count')
print count_country
               
proportion_above10k = (count_above10k['2012'] / count_country['2012'])*100
print proportion_above10k.astype('int')
# Out:
#                Country  2012
# Region
# AFRICA               5     5
# ASIA                14    14
# EUROPE              31    31
# NORTH AMERICA       13    13
# OCEANIA              2     2
# SOUTH AMERICA        5     5
#                Country  2012
# Region
# AFRICA              49    49
# ASIA                38    38
# EUROPE              43    39
# NORTH AMERICA       22    22
# OCEANIA             13    10
# SOUTH AMERICA       12    12
# Region
# AFRICA           10.204082
# ASIA             36.842105
# EUROPE           79.487179
# NORTH AMERICA    59.090909
# OCEANIA          20.000000
# SOUTH AMERICA    41.666667
# Name: 2012, dtype: float64

# %% [markdown]
# #### Problem 3(d)
#
# **For AC209 Students**: Re-run this analysis in Problem 3 but compute the average income per person for each region, instead of the average of the reported incomes per person across countries in the region. Why are these two different? Hint: use this [data set](https://spreadsheets.google.com/pub?key=phAwcNAVuyj0XOoBL_n5tAQ&gid=0).

# %%
pop = pd.read_csv('https://spreadsheets.google.com/pub?key=phAwcNAVuyj0XOoBL_n5tAQ&gid=0&output=csv')
pop.head()

pop = pop.rename(columns={'Total population':'Country', '2012':'Pop2012'}, inplace=False)
pop2012 = pop[['Country','Pop2012']]

income2012 = merged2012.rename(columns={'2012':'GDP2012'}, inplace=False)

income_pop2012 = pd.merge(income2012, pop2012, on=['Country', 'Country']).dropna()

#print income_pop2012

income_pop2012['GDP2012'] = income_pop2012['GDP2012'].astype('int')

#national_income = income_pop2012.GDP2012.astype('int') * income_pop2012.Pop2012

national_income = (income_pop2012['GDP2012'] )*( income_pop2012['Pop2012'])
income_pop2012['national_income'] = national_income
#print income_pop2012

print income_pop2012
# Out:
#                               Country         Region  GDP2012      Pop2012  \
# 0                             Algeria         AFRICA     6419   36,485,828
# 1                              Angola         AFRICA     5838   20,162,517
# 2                               Benin         AFRICA     1464    9,351,838
# 3                            Botswana         AFRICA    14045    2,053,237
# 4                             Burundi         AFRICA      484    8,749,387
# 5                            Cameroon         AFRICA     2094   20,468,943
# 6                          Cape Verde         AFRICA     3896      505,335
# 7                                Chad         AFRICA     1768   11,830,573
# 8                             Comoros         AFRICA     1027      773,344
# 9                            Djibouti         AFRICA     2244      922,708
# 10                              Egypt         AFRICA     6013   83,958,369
# 11                  Equatorial Guinea         AFRICA    13499      740,471
# 12                            Eritrea         AFRICA      613    5,580,862
# 13                           Ethiopia         AFRICA      958   86,538,534
# 14                              Gabon         AFRICA    13853    1,563,873
# 15                             Gambia         AFRICA      747    1,824,777
# 16                              Ghana         AFRICA     1728   25,545,939
# 17                             Guinea         AFRICA      965   10,480,710
# 18                      Guinea-Bissau         AFRICA      593    1,579,632
