# %% [markdown]
# # Homework 4: Can you predict the Midterm Elections?
#
# Due: Thursday, October 30, 2014 11:59 PM
#
# <a href=https://raw.githubusercontent.com/cs109/2014/master/homework/HW4.ipynb download=HW4.ipynb> Download this assignment</a>
#
# #### Submission Instructions
# To submit your homework, create a folder named lastname_firstinitial_hw# and place your IPython notebooks, data files, and any other files in this folder. Your IPython Notebooks should be completely executed with the results visible in the notebook. We should not have to run any code. Compress the folder (please use .zip compression) and submit to the CS109 dropbox in the appropriate folder. If we cannot access your work because these directions are not followed correctly, we will not grade your work. For the competition (problem 4), we will post a link on Piazza to a Google Form for you to submit your predictions.
#
#
# ---

# %% [markdown]
# ## Introduction
#
# **Add Introduction**
#
# You will use the [HuffPost Pollster API](http://elections.huffingtonpost.com/pollster/api) to extract the polls for the current 2014 Senate Midterm Elections and provide a final prediction of the result of each state.
#
# #### Data
#
# We will use the polls from the [2014 Senate Midterm Elections](http://elections.huffingtonpost.com/pollster) from the [HuffPost Pollster API](http://elections.huffingtonpost.com/pollster/api).
#
# ---

# %% [markdown]
# ## Problem 1: Data Wrangling
#
# We will read in the polls from the [2014 Senate Midterm Elections](http://elections.huffingtonpost.com/pollster) from the [HuffPost Pollster API](http://elections.huffingtonpost.com/pollster/api) and create a dictionary of DataFrames as well a master table information for each race.

# %% [markdown]
# #### Problem 1(a)
#
# Read in [this JSON object](http://elections.huffingtonpost.com/pollster/api/charts/?topic=2014-senate) containing the polls for the 2014 Senate Elections using the HuffPost API. Call this JSON object `info`.  This JSON object is imported as a list in Python where each element contains the information for one race.  Use the function `type` to confirm the that `info` is a list.

# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

import urllib2 # module to read in HTML
import bs4 # BeautifulSoup: module to parse HTML and XML
import json # 
import datetime as dt # module for manipulating dates and times
import pandas as pd
import numpy as np
import requests 
from StringIO import StringIO

# %%
url_str = "http://elections.huffingtonpost.com/pollster/api/charts/?topic=2014-senate"
election_url = [election['url'] + '.csv' for election in requests.get(url_str).json()]

Data = urllib2.urlopen(url).read()
info = json.loads(data.decode('utf-8'))
print len(info)
print type(info)
print 
info.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-496-6218860dac6e> in <module>()
#       3
#       4 Data = urllib2.urlopen(url).read()
# ----> 5 info = json.loads(data.decode('utf-8'))
#       6 print len(info)
#       7 print type(info)
#
# /Users/philtinn/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1841                 return self[name]
#    1842             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1843                                  (type(self).__name__, name))
#    1844
#    1845     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'decode'

# %% [markdown]
# #### Problem 1(b)
#
# For each element of the list in `info` extract the state. We should have one poll per state, but we do not. Why?
#
# **Hint**: Use the internet to find out information on the races in each state that has more than one entry. Eliminate entries of the list that represent races that are not happening.

# %%
states_abbrev = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
pollIndex = 35
info[pollIndex].keys()
data = pd.DataFrame(info, columns = ['last_updated', 'title', 'url', 'election_date', 'estimates', 'poll_count', 'short_title', 'topic','state','slug'])
data['state_name'] = data.state.replace(states_abbrev)
data.head()
#data.groupby('state_name').count()

#states with more than one poll are NH, OK, SC
#OK and SC include two special elections; look at NH
data[data['state']=='NH']

#remove the earlier poll on Bass who dropped out of the NH race 
dropBass = data[data.short_title !='NH Senate: Bass vs. Shaheen']
dropBass[dropBass['state']=='NH']
#dropBass[dropBass['state']=='WY']
# Out:
#            last_updated                                         title  \
# 4  2014-10-26T15:16:35Z  2014 New Hampshire Senate: Brown vs. Shaheen
#
#                                                  url election_date  \
# 4  http://elections.huffingtonpost.com/pollster/2...    2014-11-04
#
#                                            estimates  poll_count  \
# 4  [{u'first_name': u'Jeanne', u'last_name': u'Sh...          52
#
#                  short_title        topic state  \
# 4  2014 New Hampshire Senate  2014-senate    NH
#
#                                          slug     state_name
# 4  2014-new-hampshire-senate-brown-vs-shaheen  New Hampshire

# %% [markdown]
# ** Your answer here: **
#
# New Hampshire has an additional entry from 2013 before Charles Bass (Rep) withdrew from the race to be replaced by Scott Brown.
# South Carolina and Oklahoma both have a special election to replace seats for senators stepping down before the end of their official terms.

# %% [markdown]
# #### Problem 1(c)
#
# Create a dictionary of pandas DataFrames called `polls` keyed by the name of the election (a string). Each value in the dictionary should contain the polls for one of the races.

# %%
def build_frame(url):
    """
    Returns a pandas DataFrame object containing
    the data returned from the given url
    """
    source = requests.get(url).text
    
    # Use StringIO because pd.DataFrame.from_csv requires .read() method
    s = StringIO(source)
    
    return pd.DataFrame.from_csv(s, index_col=None).convert_objects(
            convert_dates="coerce", convert_numeric=True)

# Makes a dictionary of pandas DataFrames keyed on election string.
polls = dict((election.split("/")[-1][:-4], build_frame(election)) for election in election_urls)

polls.keys()
#len(polls)
#polls['2014-kentucky-senate-mcconnell-vs-grimes']
# Out:
# [u'2014-kentucky-senate-mcconnell-vs-grimes',
#  u'2014-montana-senate-daines-vs-curtis',
#  u'2014-north-carolina-senate-tillis-vs-hagan',
#  u'2014-tennessee-senate-alexander-vs-ball',
#  u'2014-michigan-senate-land-vs-peters',
#  u'2014-wyoming-senate',
#  u'2014-alaska-senate-sullivan-vs-begich',
#  u'2014-oregon-senate-wehby-vs-merkley',
#  u'2014-new-hampshire-senate-brown-vs-shaheen',
#  u'2014-mississippi-senate-cochran-vs-childers',
#  u'2014-rhode-island-senate-zaccaria-vs-reed',
#  u'2014-new-jersey-senate-bell-vs-booker',
#  u'2014-virginia-senate-gillespie-vs-warner',
#  u'2014-south-dakota-senate-rounds-vs-weiland',
#  u'2014-nebraska-senate-sasse-vs-domina',
#  u'2014-iowa-senate-ernst-vs-braley',
#  u'2014-oklahoma-senate-inhofe-vs-silverstein',
#  u'2014-illinois-senate-oberweis-vs-durbin',
#  u'2014-south-carolina-senate-graham-vs-hutto',
#  u'2014-maine-senate-collins-vs-bellows',
#  u'2014-west-virginia-senate-capito-vs-tennant',
#  u'2014-hawaii-senate-cavasso-vs-schatz',
#  u'2014-delaware-senate-wade-vs-coons',
#  u'2014-massachusetts-senate-herr-vs-markey',
#  u'2014-minnesota-senate-mcfadden-vs-franken',
#  u'2014-louisiana-senate-cassidy-vs-landrieu',
#  u'2014-georgia-senate-perdue-vs-nunn',
#  u'2014-kansas-senate-roberts-vs-orman-vs-taylor',
#  u'2014-oklahoma-senate-lankford-vs-johnson',
#  u'2014-new-mexico-senate-weh-vs-udall',
#  u'2014-idaho-senate-risch-vs-mitchell',
#  u'2014-texas-senate-cornyn-vs-alameel',
#  u'2014-arkansas-senate-cotton-vs-pryor',
#  u'2014-south-carolina-senate-scott-vs-dickerson',
#  u'2014-colorado-senate-gardner-vs-udall',
#  u'2014-new-hampshire-senate-bass-vs-shaheen']

# %% [markdown]
# #### Problem 1(d)
#
# Now creaate a master table information containing information about each race. Create a pandas DataFrame called `candidates` with rows containing information about each race. The `candidates` DataFrame should have the following columns:
#
# 1. `State` = entries should be unique
# 2. `R` = name of republican candidate
# 3. `D` = name of non-republican candidate (Democrate or Independent)
# 4. `incumbent` = R, D or NA
#
# **Hint**: You will need a considerable amount of data wrangling for this.

# %%
info
# Out:
# [{u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'McConnell',
#     u'first_name': u'Mitch',
#     u'incumbent': True,
#     u'last_name': u'McConnell',
#     u'lead_confidence': 99.9,
#     u'party': u'Rep',
#     u'value': 46.5},
#    {u'choice': u'Grimes',
#     u'first_name': u'Alison Lundergan',
#     u'incumbent': False,
#     u'last_name': u'Grimes',
#     u'lead_confidence': 0.1,
#     u'party': u'Dem',
#     u'value': 42.3}],
#   u'last_updated': u'2014-10-26T15:00:07Z',
#   u'poll_count': 53,
#   u'short_title': u'2014 Kentucky Senate',
#   u'slug': u'2014-kentucky-senate-mcconnell-vs-grimes',
#   u'state': u'KY',
#   u'title': u'2014 Kentucky Senate: McConnell vs. Grimes',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-kentucky-senate-mcconnell-vs-grimes'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Cotton',
#     u'first_name': u'Tom',
#     u'incumbent': False,
#     u'last_name': u'Cotton',
#     u'lead_confidence': 99.2,
#     u'party': u'Rep',
#     u'value': 47.9},
#    {u'choice': u'Pryor',
#     u'first_name': u'Mark',
#     u'incumbent': True,
#     u'last_name': u'Pryor',
#     u'lead_confidence': 0.8,
#     u'party': u'Dem',
#     u'value': 44.0}],
#   u'last_updated': u'2014-10-26T14:35:13Z',
#   u'poll_count': 57,
#   u'short_title': u'2014 Arkansas Senate',
#   u'slug': u'2014-arkansas-senate-cotton-vs-pryor',
#   u'state': u'AR',
#   u'title': u'2014 Arkansas Senate: Cotton vs. Pryor',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-arkansas-senate-cotton-vs-pryor'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Peters',
#     u'first_name': u'Gary',
#     u'incumbent': False,
#     u'last_name': u'Peters',
#     u'lead_confidence': 100.0,
#     u'party': u'Dem',
#     u'value': 50.0},
#    {u'choice': u'Land',
#     u'first_name': u'Terri Lynn',
#     u'incumbent': False,
#     u'last_name': u'Land',
#     u'lead_confidence': 0.0,
#     u'party': u'Rep',
#     u'value': 38.8}],
#   u'last_updated': u'2014-10-26T15:09:08Z',
#   u'poll_count': 57,
#   u'short_title': u'2014 Michigan Senate',
#   u'slug': u'2014-michigan-senate-land-vs-peters',
#   u'state': u'MI',
#   u'title': u'2014 Michigan Senate: Land vs. Peters',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-michigan-senate-land-vs-peters'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Cassidy',
#     u'first_name': u'Bill',
#     u'incumbent': False,
#     u'last_name': u'Cassidy',
#     u'lead_confidence': 99.8,
#     u'party': u'Rep',
#     u'value': 47.1},
#    {u'choice': u'Landrieu',
#     u'first_name': u'Mary',
#     u'incumbent': True,
#     u'last_name': u'Landrieu',
#     u'lead_confidence': 0.2,
#     u'party': u'Dem',
#     u'value': 42.3},
#    {u'choice': u'Other',
#     u'first_name': None,
#     u'incumbent': None,
#     u'last_name': None,
#     u'lead_confidence': None,
#     u'party': None,
#     u'value': 0.9}],
#   u'last_updated': u'2014-10-26T15:04:22Z',
#   u'poll_count': 29,
#   u'short_title': u'2014 Louisiana Senate',
#   u'slug': u'2014-louisiana-senate-cassidy-vs-landrieu',
#   u'state': u'LA',
#   u'title': u'2014 Louisiana Senate: Cassidy vs. Landrieu',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-louisiana-senate-cassidy-vs-landrieu'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Shaheen',
#     u'first_name': u'Jeanne',
#     u'incumbent': True,
#     u'last_name': u'Shaheen',
#     u'lead_confidence': 97.9,
#     u'party': u'Dem',
#     u'value': 47.3},
#    {u'choice': u'Brown',
#     u'first_name': u'Scott',
#     u'incumbent': False,
#     u'last_name': u'Brown',
#     u'lead_confidence': 2.1,
#     u'party': u'Rep',
#     u'value': 44.5}],
#   u'last_updated': u'2014-10-26T15:16:35Z',
#   u'poll_count': 52,
#   u'short_title': u'2014 New Hampshire Senate',
#   u'slug': u'2014-new-hampshire-senate-brown-vs-shaheen',
#   u'state': u'NH',
#   u'title': u'2014 New Hampshire Senate: Brown vs. Shaheen',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-new-hampshire-senate-brown-vs-shaheen'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Capito',
#     u'first_name': u'Shelley',
#     u'incumbent': False,
#     u'last_name': u'Moore Capito',
#     u'lead_confidence': 100.0,
#     u'party': u'Rep',
#     u'value': 53.6},
#    {u'choice': u'Tennant',
#     u'first_name': u'Natalie',
#     u'incumbent': False,
#     u'last_name': u'Tennant',
#     u'lead_confidence': 0.0,
#     u'party': u'Dem',
#     u'value': 35.6}],
#   u'last_updated': u'2014-10-26T15:04:28Z',
#   u'poll_count': 14,
#   u'short_title': u'2014 West Virginia Senate',
#   u'slug': u'2014-west-virginia-senate-capito-vs-tennant',
#   u'state': u'WV',
#   u'title': u'2014 West Virginia Senate: Capito vs. Tennant',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-west-virginia-senate-capito-vs-tennant'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [],
#   u'last_updated': u'2013-10-28T17:33:36Z',
#   u'poll_count': 3,
#   u'short_title': u'NH Senate: Bass vs. Shaheen',
#   u'slug': u'2014-new-hampshire-senate-bass-vs-shaheen',
#   u'state': u'NH',
#   u'title': u'2014 New Hampshire Senate: Bass vs. Shaheen',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-new-hampshire-senate-bass-vs-shaheen'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Hagan',
#     u'first_name': u'Kay',
#     u'incumbent': True,
#     u'last_name': u'Hagan',
#     u'lead_confidence': 94.6,
#     u'party': u'Dem',
#     u'value': 42.3},
#    {u'choice': u'Tillis',
#     u'first_name': u'Thom',
#     u'incumbent': False,
#     u'last_name': u'Tillis',
#     u'lead_confidence': 5.4,
#     u'party': u'Rep',
#     u'value': 40.1},
#    {u'choice': u'Haugh',
#     u'first_name': u'Sean',
#     u'incumbent': False,
#     u'last_name': u'Haugh',
#     u'lead_confidence': None,
#     u'party': u'Lib',
#     u'value': 4.9}],
#   u'last_updated': u'2014-10-26T14:43:25Z',
#   u'poll_count': 62,
#   u'short_title': u'2014 North Carolina Senate',
#   u'slug': u'2014-north-carolina-senate-tillis-vs-hagan',
#   u'state': u'NC',
#   u'title': u'2014 North Carolina Senate: Tillis vs. Hagan',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-north-carolina-senate-tillis-vs-hagan'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Warner',
#     u'first_name': u'Mark',
#     u'incumbent': True,
#     u'last_name': u'Warner',
#     u'lead_confidence': 100.0,
#     u'party': u'Dem',
#     u'value': 48.6},
#    {u'choice': u'Gillespie',
#     u'first_name': u'Ed',
#     u'incumbent': False,
#     u'last_name': u'Gillespie',
#     u'lead_confidence': 0.0,
#     u'party': u'Rep',
#     u'value': 33.7}],
#   u'last_updated': u'2014-10-26T15:08:06Z',
#   u'poll_count': 20,
#   u'short_title': u'2014 Virginia Senate',
#   u'slug': u'2014-virginia-senate-gillespie-vs-warner',
#   u'state': u'VA',
#   u'title': u'2014 Virginia Senate: Gillespie vs. Warner',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-virginia-senate-gillespie-vs-warner'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Gardner',
#     u'first_name': u'Cory',
#     u'incumbent': False,
#     u'last_name': u'Gardner',
#     u'lead_confidence': 98.8,
#     u'party': u'Rep',
#     u'value': 47.1},
#    {u'choice': u'Udall',
#     u'first_name': u'Mark',
#     u'incumbent': True,
#     u'last_name': u'Udall',
#     u'lead_confidence': 1.2,
#     u'party': u'Dem',
#     u'value': 44.9}],
#   u'last_updated': u'2014-10-26T14:36:41Z',
#   u'poll_count': 44,
#   u'short_title': u'2014 Colorado Senate',
#   u'slug': u'2014-colorado-senate-gardner-vs-udall',
#   u'state': u'CO',
#   u'title': u'2014 Colorado Senate: Gardner vs. Udall',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-colorado-senate-gardner-vs-udall'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Durbin',
#     u'first_name': u'Dick',
#     u'incumbent': True,
#     u'last_name': u'Durbin',
#     u'lead_confidence': 100.0,
#     u'party': u'Dem',
#     u'value': 51.3},
#    {u'choice': u'Oberweis',
#     u'first_name': u'Jim',
#     u'incumbent': False,
#     u'last_name': u'Oberweis',
#     u'lead_confidence': 0.0,
#     u'party': u'Rep',
#     u'value': 38.5},
#    {u'choice': u'Other',
#     u'first_name': None,
#     u'incumbent': None,
#     u'last_name': None,
#     u'lead_confidence': None,
#     u'party': None,
#     u'value': 3.1}],
#   u'last_updated': u'2014-10-26T15:43:57Z',
#   u'poll_count': 14,
#   u'short_title': u'IL Senate: Oberweis vs. Durbin',
#   u'slug': u'2014-illinois-senate-oberweis-vs-durbin',
#   u'state': u'IL',
#   u'title': u'2014 Illinois Senate: Oberweis vs. Durbin',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-illinois-senate-oberweis-vs-durbin'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Sullivan',
#     u'first_name': u'Dan',
#     u'incumbent': False,
#     u'last_name': u'Sullivan',
#     u'lead_confidence': 99.0,
#     u'party': u'Rep',
#     u'value': 48.4},
#    {u'choice': u'Begich',
#     u'first_name': u'Mark',
#     u'incumbent': True,
#     u'last_name': u'Begich',
#     u'lead_confidence': 1.0,
#     u'party': u'Dem',
#     u'value': 44.3}],
#   u'last_updated': u'2014-10-26T14:47:01Z',
#   u'poll_count': 30,
#   u'short_title': u'2014 Alaska Senate: Sullivan vs. Begich',
#   u'slug': u'2014-alaska-senate-sullivan-vs-begich',
#   u'state': u'AK',
#   u'title': u'2014 Alaska Senate: Sullivan vs. Begich',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-alaska-senate-sullivan-vs-begich'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Ernst',
#     u'first_name': u'Joni',
#     u'incumbent': False,
#     u'last_name': u'Ernst',
#     u'lead_confidence': 82.7,
#     u'party': u'Rep',
#     u'value': 45.7},
#    {u'choice': u'Braley',
#     u'first_name': u'Bruce',
#     u'incumbent': False,
#     u'last_name': u'Braley',
#     u'lead_confidence': 17.3,
#     u'party': u'Dem',
#     u'value': 44.0}],
#   u'last_updated': u'2014-10-26T14:39:23Z',
#   u'poll_count': 44,
#   u'short_title': u'2014 Iowa Senate',
#   u'slug': u'2014-iowa-senate-ernst-vs-braley',
#   u'state': u'IA',
#   u'title': u'2014 Iowa Senate: Ernst vs. Braley',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-iowa-senate-ernst-vs-braley'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Cochran',
#     u'first_name': u'Thad',
#     u'incumbent': True,
#     u'last_name': u'Cochran',
#     u'lead_confidence': 100.0,
#     u'party': u'Rep',
#     u'value': 44.2},
#    {u'choice': u'Childers',
#     u'first_name': u'Travis',
#     u'incumbent': False,
#     u'last_name': u'Childers',
#     u'lead_confidence': 0.0,
#     u'party': u'Dem',
#     u'value': 26.7},
#    {u'choice': u'Other',
#     u'first_name': None,
#     u'incumbent': None,
#     u'last_name': None,
#     u'lead_confidence': None,
#     u'party': None,
#     u'value': 9.0}],
#   u'last_updated': u'2014-10-26T15:11:17Z',
#   u'poll_count': 8,
#   u'short_title': u'2014 Mississippi Senate',
#   u'slug': u'2014-mississippi-senate-cochran-vs-childers',
#   u'state': u'MS',
#   u'title': u'2014 Mississippi Senate: Cochran vs. Childers',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-mississippi-senate-cochran-vs-childers'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Merkley',
#     u'first_name': u'Jeff',
#     u'incumbent': True,
#     u'last_name': u'Merkley',
#     u'lead_confidence': 100.0,
#     u'party': u'Dem',
#     u'value': 51.9},
#    {u'choice': u'Wehby',
#     u'first_name': u'Monica',
#     u'incumbent': False,
#     u'last_name': u'Wehby',
#     u'lead_confidence': 0.0,
#     u'party': u'Rep',
#     u'value': 35.7}],
#   u'last_updated': u'2014-10-26T15:22:38Z',
#   u'poll_count': 17,
#   u'short_title': u'2014 Oregon Senate',
#   u'slug': u'2014-oregon-senate-wehby-vs-merkley',
#   u'state': u'OR',
#   u'title': u'2014 Oregon Senate: Wehby vs. Merkley',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-oregon-senate-wehby-vs-merkley'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Perdue',
#     u'first_name': u'David',
#     u'incumbent': False,
#     u'last_name': u'Perdue',
#     u'lead_confidence': 95.3,
#     u'party': u'Rep',
#     u'value': 44.6},
#    {u'choice': u'Nunn',
#     u'first_name': u'Michelle',
#     u'incumbent': False,
#     u'last_name': u'Nunn',
#     u'lead_confidence': 4.7,
#     u'party': u'Dem',
#     u'value': 42.6},
#    {u'choice': u'Swafford',
#     u'first_name': u'Amanda',
#     u'incumbent': False,
#     u'last_name': u'Swafford',
#     u'lead_confidence': None,
#     u'party': u'Lib',
#     u'value': 3.9}],
#   u'last_updated': u'2014-10-26T14:56:29Z',
#   u'poll_count': 39,
#   u'short_title': u'2014 Georgia Senate',
#   u'slug': u'2014-georgia-senate-perdue-vs-nunn',
#   u'state': u'GA',
#   u'title': u'2014 Georgia Senate: Perdue vs. Nunn',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-georgia-senate-perdue-vs-nunn'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Sasse',
#     u'first_name': u'Ben',
#     u'incumbent': False,
#     u'last_name': u'Sasse',
#     u'lead_confidence': 100.0,
#     u'party': u'Rep',
#     u'value': 57.4},
#    {u'choice': u'Domina',
#     u'first_name': u'David',
#     u'incumbent': False,
#     u'last_name': u'Domina',
#     u'lead_confidence': 0.0,
#     u'party': u'Dem',
#     u'value': 30.4}],
#   u'last_updated': u'2014-10-26T15:13:42Z',
#   u'poll_count': 6,
#   u'short_title': u'2014 Nebraska Senate: Sasse vs. Domina',
#   u'slug': u'2014-nebraska-senate-sasse-vs-domina',
#   u'state': u'NE',
#   u'title': u'2014 Nebraska Senate: Sasse vs. Domina',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-nebraska-senate-sasse-vs-domina'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Rounds',
#     u'first_name': u'Mike',
#     u'incumbent': False,
#     u'last_name': u'Rounds',
#     u'lead_confidence': 100.0,
#     u'party': u'Rep',
#     u'value': 37.6},
#    {u'choice': u'Weiland',
#     u'first_name': u'Rick',
#     u'incumbent': False,
#     u'last_name': u'Weiland',
#     u'lead_confidence': 0.0,
#     u'party': u'Dem',
#     u'value': 26.2},
#    {u'choice': u'Pressler',
#     u'first_name': u'Larry',
#     u'incumbent': False,
#     u'last_name': u'Pressler',
#     u'lead_confidence': None,
#     u'party': u'Ind',
#     u'value': 20.4},
#    {u'choice': u'Other',
#     u'first_name': None,
#     u'incumbent': None,
#     u'last_name': None,
#     u'lead_confidence': None,
#     u'party': None,
#     u'value': 3.1}],
#   u'last_updated': u'2014-10-26T14:44:39Z',
#   u'poll_count': 21,
#   u'short_title': u'2014 South Dakota Senate',
#   u'slug': u'2014-south-dakota-senate-rounds-vs-weiland',
#   u'state': u'SD',
#   u'title': u'2014 South Dakota Senate: Rounds vs. Weiland',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-south-dakota-senate-rounds-vs-weiland'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Collins',
#     u'first_name': u'Susan',
#     u'incumbent': True,
#     u'last_name': u'Collins',
#     u'lead_confidence': 100.0,
#     u'party': u'Rep',
#     u'value': 56.6},
#    {u'choice': u'Bellows',
#     u'first_name': u'Shenna',
#     u'incumbent': False,
#     u'last_name': u'Bellows',
#     u'lead_confidence': 0.0,
#     u'party': u'Dem',
#     u'value': 33.9}],
#   u'last_updated': u'2014-10-26T15:08:18Z',
#   u'poll_count': 10,
#   u'short_title': u'2014 Maine Senate',
#   u'slug': u'2014-maine-senate-collins-vs-bellows',
#   u'state': u'ME',
#   u'title': u'2014 Maine Senate: Collins vs. Bellows',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-maine-senate-collins-vs-bellows'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Franken',
#     u'first_name': u'Al',
#     u'incumbent': True,
#     u'last_name': u'Franken',
#     u'lead_confidence': 100.0,
#     u'party': u'Dem',
#     u'value': 51.8},
#    {u'choice': u'McFadden',
#     u'first_name': u'Mike',
#     u'incumbent': False,
#     u'last_name': u'McFadden',
#     u'lead_confidence': 0.0,
#     u'party': u'Rep',
#     u'value': 39.8}],
#   u'last_updated': u'2014-10-26T16:00:58Z',
#   u'poll_count': 20,
#   u'short_title': u'2014 Minnesota Senate',
#   u'slug': u'2014-minnesota-senate-mcfadden-vs-franken',
#   u'state': u'MN',
#   u'title': u'2014 Minnesota Senate: McFadden vs. Franken',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-minnesota-senate-mcfadden-vs-franken'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Cornyn',
#     u'first_name': u'John',
#     u'incumbent': True,
#     u'last_name': u'Cornyn',
#     u'lead_confidence': 100.0,
#     u'party': u'Rep',
#     u'value': 54.1},
#    {u'choice': u'Alameel',
#     u'first_name': u'David',
#     u'incumbent': False,
#     u'last_name': u'Alameel',
#     u'lead_confidence': 0.0,
#     u'party': u'Dem',
#     u'value': 30.4},
#    {u'choice': u'Other',
#     u'first_name': None,
#     u'incumbent': None,
#     u'last_name': None,
#     u'lead_confidence': None,
#     u'party': None,
#     u'value': 1.0}],
#   u'last_updated': u'2014-10-26T15:27:24Z',
#   u'poll_count': 9,
#   u'short_title': u'2014 Texas Senate',
#   u'slug': u'2014-texas-senate-cornyn-vs-alameel',
#   u'state': u'TX',
#   u'title': u'2014 Texas Senate: Cornyn vs. Alameel',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-texas-senate-cornyn-vs-alameel'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Graham',
#     u'first_name': u'Lindsey',
#     u'incumbent': True,
#     u'last_name': u'Graham',
#     u'lead_confidence': 100.0,
#     u'party': u'Rep',
#     u'value': 47.6},
#    {u'choice': u'Hutto',
#     u'first_name': u'Brad',
#     u'incumbent': False,
#     u'last_name': u'Hutto',
#     u'lead_confidence': 0.0,
#     u'party': u'Dem',
#     u'value': 29.5},
#    {u'choice': u'Other',
#     u'first_name': None,
#     u'incumbent': None,
#     u'last_name': None,
#     u'lead_confidence': None,
#     u'party': None,
#     u'value': 10.0}],
#   u'last_updated': u'2014-10-26T15:25:34Z',
#   u'poll_count': 8,
#   u'short_title': u'2014 South Carolina Senate: Graham vs. Hutto',
#   u'slug': u'2014-south-carolina-senate-graham-vs-hutto',
#   u'state': u'SC',
#   u'title': u'2014 South Carolina Senate: Graham vs. Hutto',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-south-carolina-senate-graham-vs-hutto'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Scott',
#     u'first_name': u'Tim',
#     u'incumbent': True,
#     u'last_name': u'Scott',
#     u'lead_confidence': 100.0,
#     u'party': u'Rep',
#     u'value': 55.1},
#    {u'choice': u'Dickerson',
#     u'first_name': u'Joyce',
#     u'incumbent': False,
#     u'last_name': u'Dickerson',
#     u'lead_confidence': 0.0,
#     u'party': u'Dem',
#     u'value': 27.5}],
#   u'last_updated': u'2014-10-26T15:25:34Z',
#   u'poll_count': 6,
#   u'short_title': u'2014 South Carolina Senate: Scott vs. Dickerson',
#   u'slug': u'2014-south-carolina-senate-scott-vs-dickerson',
#   u'state': u'SC',
#   u'title': u'2014 South Carolina Senate: Scott vs. Dickerson',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-south-carolina-senate-scott-vs-dickerson'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Inhofe',
#     u'first_name': u'Jim',
#     u'incumbent': True,
#     u'last_name': u'Inhofe',
#     u'lead_confidence': None,
#     u'party': u'Rep',
#     u'value': 63.0},
#    {u'choice': u'Silverstein',
#     u'first_name': u'Matt',
#     u'incumbent': False,
#     u'last_name': u'Silverstein',
#     u'lead_confidence': None,
#     u'party': u'Dem',
#     u'value': 27.0},
#    {u'choice': u'Undecided',
#     u'first_name': None,
#     u'incumbent': None,
#     u'last_name': None,
#     u'lead_confidence': None,
#     u'party': None,
#     u'value': 8.0}],
#   u'last_updated': u'2014-10-26T15:20:35Z',
#   u'poll_count': 5,
#   u'short_title': u'2014 Oklahoma Senate: Inhofe vs. Silverstein',
#   u'slug': u'2014-oklahoma-senate-inhofe-vs-silverstein',
#   u'state': u'OK',
#   u'title': u'2014 Oklahoma Senate: Inhofe vs. Silverstein',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-oklahoma-senate-inhofe-vs-silverstein'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Udall',
#     u'first_name': u'Tom',
#     u'incumbent': True,
#     u'last_name': u'Udall',
#     u'lead_confidence': 100.0,
#     u'party': u'Dem',
#     u'value': 51.9},
#    {u'choice': u'Weh',
#     u'first_name': u'Allen',
#     u'incumbent': False,
#     u'last_name': u'Weh',
#     u'lead_confidence': 0.0,
#     u'party': u'Rep',
#     u'value': 35.5},
#    {u'choice': u'Other',
#     u'first_name': None,
#     u'incumbent': None,
#     u'last_name': None,
#     u'lead_confidence': None,
#     u'party': None,
#     u'value': 1.0}],
#   u'last_updated': u'2014-10-26T15:19:27Z',
#   u'poll_count': 10,
#   u'short_title': u'2014 New Mexico Senate',
#   u'slug': u'2014-new-mexico-senate-weh-vs-udall',
#   u'state': u'NM',
#   u'title': u'2014 New Mexico Senate: Weh vs. Udall',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-new-mexico-senate-weh-vs-udall'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Booker',
#     u'first_name': u'Cory',
#     u'incumbent': True,
#     u'last_name': u'Booker',
#     u'lead_confidence': 100.0,
#     u'party': u'Dem',
#     u'value': 53.6},
#    {u'choice': u'Bell',
#     u'first_name': u'Jeff',
#     u'incumbent': False,
#     u'last_name': u'Bell',
#     u'lead_confidence': 0.0,
#     u'party': u'Rep',
#     u'value': 36.4},
#    {u'choice': u'Other',
#     u'first_name': None,
#     u'incumbent': None,
#     u'last_name': None,
#     u'lead_confidence': None,
#     u'party': None,
#     u'value': 0.9}],
#   u'last_updated': u'2014-10-26T15:18:37Z',
#   u'poll_count': 13,
#   u'short_title': u'2014 New Jersey Senate',
#   u'slug': u'2014-new-jersey-senate-bell-vs-booker',
#   u'state': u'NJ',
#   u'title': u'2014 New Jersey Senate: Bell vs. Booker',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-new-jersey-senate-bell-vs-booker'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Risch',
#     u'first_name': u'Jim',
#     u'incumbent': True,
#     u'last_name': u'Risch',
#     u'lead_confidence': 100.0,
#     u'party': u'Rep',
#     u'value': 57.7},
#    {u'choice': u'Mitchell',
#     u'first_name': u'Nels',
#     u'incumbent': False,
#     u'last_name': u'Mitchell',
#     u'lead_confidence': 0.0,
#     u'party': u'Dem',
#     u'value': 29.3}],
#   u'last_updated': u'2014-10-26T14:58:06Z',
#   u'poll_count': 6,
#   u'short_title': u'2014 Idaho Senate',
#   u'slug': u'2014-idaho-senate-risch-vs-mitchell',
#   u'state': u'ID',
#   u'title': u'2014 Idaho Senate: Risch vs. Mitchell',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-idaho-senate-risch-vs-mitchell'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Alexander',
#     u'first_name': u'Lamar',
#     u'incumbent': True,
#     u'last_name': u'Alexander',
#     u'lead_confidence': 100.0,
#     u'party': u'Rep',
#     u'value': 55.1},
#    {u'choice': u'Ball',
#     u'first_name': u'Gordon',
#     u'incumbent': False,
#     u'last_name': u'Ball',
#     u'lead_confidence': 0.0,
#     u'party': u'Dem',
#     u'value': 32.6},
#    {u'choice': u'Other',
#     u'first_name': None,
#     u'incumbent': None,
#     u'last_name': None,
#     u'lead_confidence': None,
#     u'party': None,
#     u'value': 1.2}],
#   u'last_updated': u'2014-10-26T15:26:32Z',
#   u'poll_count': 6,
#   u'short_title': u'2014 Tennessee Senate',
#   u'slug': u'2014-tennessee-senate-alexander-vs-ball',
#   u'state': u'TN',
#   u'title': u'2014 Tennessee Senate: Alexander vs. Ball',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-tennessee-senate-alexander-vs-ball'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Enzi',
#     u'first_name': u'Mike',
#     u'incumbent': True,
#     u'last_name': u'Enzi',
#     u'lead_confidence': None,
#     u'party': u'Rep',
#     u'value': 67.0},
#    {u'choice': u'Hardy',
#     u'first_name': u'Charlie',
#     u'incumbent': False,
#     u'last_name': u'Hardy',
#     u'lead_confidence': None,
#     u'party': u'Dem',
#     u'value': 27.0},
#    {u'choice': u'Undecided',
#     u'first_name': None,
#     u'incumbent': None,
#     u'last_name': None,
#     u'lead_confidence': None,
#     u'party': None,
#     u'value': 6.0}],
#   u'last_updated': u'2014-10-26T15:00:29Z',
#   u'poll_count': 5,
#   u'short_title': u'2014 Wyoming Senate',
#   u'slug': u'2014-wyoming-senate',
#   u'state': u'WY',
#   u'title': u'2014 Wyoming Senate',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-wyoming-senate'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Roberts',
#     u'first_name': u'Pat',
#     u'incumbent': True,
#     u'last_name': u'Roberts',
#     u'lead_confidence': 65.6,
#     u'party': u'Rep',
#     u'value': 44.3},
#    {u'choice': u'Orman',
#     u'first_name': u'Greg',
#     u'incumbent': False,
#     u'last_name': u'Orman',
#     u'lead_confidence': 34.4,
#     u'party': u'ind',
#     u'value': 42.9}],
#   u'last_updated': u'2014-10-26T14:40:10Z',
#   u'poll_count': 22,
#   u'short_title': u'2014 Kansas Senate',
#   u'slug': u'2014-kansas-senate-roberts-vs-orman-vs-taylor',
#   u'state': u'KS',
#   u'title': u'2014 Kansas Senate',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-kansas-senate-roberts-vs-orman-vs-taylor'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Schatz',
#     u'first_name': u'Brian',
#     u'incumbent': True,
#     u'last_name': u'Schatz',
#     u'lead_confidence': 100.0,
#     u'party': u'Dem',
#     u'value': 68.8},
#    {u'choice': u'Cavasso',
#     u'first_name': u'Campbell',
#     u'incumbent': False,
#     u'last_name': u'Cavasso',
#     u'lead_confidence': 0.0,
#     u'party': u'Rep',
#     u'value': 19.9},
#    {u'choice': u'Other',
#     u'first_name': None,
#     u'incumbent': None,
#     u'last_name': None,
#     u'lead_confidence': None,
#     u'party': None,
#     u'value': 1.0}],
#   u'last_updated': u'2014-10-26T14:57:17Z',
#   u'poll_count': 6,
#   u'short_title': u'2014 Hawaii Senate',
#   u'slug': u'2014-hawaii-senate-cavasso-vs-schatz',
#   u'state': u'HI',
#   u'title': u'2014 Hawaii Senate: Cavasso vs. Schatz',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-hawaii-senate-cavasso-vs-schatz'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Lankford',
#     u'first_name': u'James',
#     u'incumbent': False,
#     u'last_name': u'Lankford',
#     u'lead_confidence': None,
#     u'party': u'Rep',
#     u'value': 63.0},
#    {u'choice': u'Johnson',
#     u'first_name': u'Connie',
#     u'incumbent': False,
#     u'last_name': u'Johnson',
#     u'lead_confidence': None,
#     u'party': u'Dem',
#     u'value': 29.0},
#    {u'choice': u'Undecided',
#     u'first_name': None,
#     u'incumbent': None,
#     u'last_name': None,
#     u'lead_confidence': None,
#     u'party': None,
#     u'value': 8.0}],
#   u'last_updated': u'2014-10-26T15:20:35Z',
#   u'poll_count': 5,
#   u'short_title': u'2014 Oklahoma Senate: Lankford vs. Johnson',
#   u'slug': u'2014-oklahoma-senate-lankford-vs-johnson',
#   u'state': u'OK',
#   u'title': u'2014 Oklahoma Senate: Lankford vs. Johnson',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-oklahoma-senate-lankford-vs-johnson'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Daines',
#     u'first_name': u'Steve',
#     u'incumbent': False,
#     u'last_name': u'Daines',
#     u'lead_confidence': None,
#     u'party': u'Rep',
#     u'value': 56.0},
#    {u'choice': u'Curtis',
#     u'first_name': u'Amanda',
#     u'incumbent': False,
#     u'last_name': u'Curtis',
#     u'lead_confidence': None,
#     u'party': u'Dem',
#     u'value': 38.0},
#    {u'choice': u'Undecided',
#     u'first_name': None,
#     u'incumbent': None,
#     u'last_name': None,
#     u'lead_confidence': None,
#     u'party': None,
#     u'value': 6.0}],
#   u'last_updated': u'2014-10-26T15:12:11Z',
#   u'poll_count': 6,
#   u'short_title': u'2014 Montana Senate: Daines vs. Curtis',
#   u'slug': u'2014-montana-senate-daines-vs-curtis',
#   u'state': u'MT',
#   u'title': u'2014 Montana Senate: Daines vs. Curtis',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-montana-senate-daines-vs-curtis'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [],
#   u'last_updated': u'2014-10-26T15:24:13Z',
#   u'poll_count': 4,
#   u'short_title': u'2014 Rhode Island Senate: Zaccaria vs. Reed',
#   u'slug': u'2014-rhode-island-senate-zaccaria-vs-reed',
#   u'state': u'RI',
#   u'title': u'2014 Rhode Island Senate: Zaccaria vs. Reed',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-rhode-island-senate-zaccaria-vs-reed'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Markey',
#     u'first_name': u'Ed',
#     u'incumbent': True,
#     u'last_name': u'Markey',
#     u'lead_confidence': 100.0,
#     u'party': u'Dem',
#     u'value': 49.7},
#    {u'choice': u'Herr',
#     u'first_name': u'Brian',
#     u'incumbent': False,
#     u'last_name': u'Herr',
#     u'lead_confidence': 0.0,
#     u'party': u'Rep',
#     u'value': 28.2}],
#   u'last_updated': u'2014-10-26T15:07:08Z',
#   u'poll_count': 9,
#   u'short_title': u'2014 Massachusetts Senate: Herr vs. Markey',
#   u'slug': u'2014-massachusetts-senate-herr-vs-markey',
#   u'state': u'MA',
#   u'title': u'2014 Massachusetts Senate: Herr vs. Markey',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-massachusetts-senate-herr-vs-markey'},
#  {u'election_date': u'2014-11-04',
#   u'estimates': [{u'choice': u'Coons',
#     u'first_name': u'Chris',
#     u'incumbent': True,
#     u'last_name': u'Coons',
#     u'lead_confidence': None,
#     u'party': u'Dem',
#     u'value': 54.0},
#    {u'choice': u'Wade',
#     u'first_name': u'Kevin',
#     u'incumbent': False,
#     u'last_name': u'Wade',
#     u'lead_confidence': None,
#     u'party': u'Rep',
#     u'value': 36.0},
#    {u'choice': u'Undecided',
#     u'first_name': None,
#     u'incumbent': None,
#     u'last_name': None,
#     u'lead_confidence': None,
#     u'party': None,
#     u'value': 10.0}],
#   u'last_updated': u'2014-10-26T14:52:36Z',
#   u'poll_count': 5,
#   u'short_title': u'2014 Delaware Senate: Wade vs. Coons',
#   u'slug': u'2014-delaware-senate-wade-vs-coons',
#   u'state': u'DE',
#   u'title': u'2014 Delaware Senate: Wade vs. Coons',
#   u'topic': u'2014-senate',
#   u'url': u'http://elections.huffingtonpost.com/pollster/2014-delaware-senate-wade-vs-coons'}]

# %%
info[7]['estimates']
#mt[1]['estimates'][0]['choice']
# Out:
# [{u'choice': u'Hagan',
#   u'first_name': u'Kay',
#   u'incumbent': True,
#   u'last_name': u'Hagan',
#   u'lead_confidence': 94.6,
#   u'party': u'Dem',
#   u'value': 42.3},
#  {u'choice': u'Tillis',
#   u'first_name': u'Thom',
#   u'incumbent': False,
#   u'last_name': u'Tillis',
#   u'lead_confidence': 5.4,
#   u'party': u'Rep',
#   u'value': 40.1},
#  {u'choice': u'Haugh',
#   u'first_name': u'Sean',
#   u'incumbent': False,
#   u'last_name': u'Haugh',
#   u'lead_confidence': None,
#   u'party': u'Lib',
#   u'value': 4.9}]

# %%
#columns = ['States','R', 'D','incumbent']
#candidates = pd.DataFrame(columns=columns)
#candidates['States'] = polls['state']

races = len(info)
cand = []

for r in range(races):
    states = (info[r]['state'])
    if info[r]['estimates'][0]['party'] == 'Rep':
            R = (info[r]['estimates'][0]['choice'])
            D = (info[r]['estimates'][1]['choice'])
    elif info[r]['estimates'][0]['party'] == 'Dem':
            R = (info[r]['estimates'][1]['choice'])
            D = (info[r]['estimates'][0]['choice'])
        #elif info[r]['estimates'][c]['party'] == 'Ind':
            # = (info[r]['estimates'][c]['choice'])
    else:
            R = "NA"
            D = "NA"
            
    cand.append([states, R, D])

cand
#for c in range(len(mt[r]['estimates'])):  
    #if mt[2]['estimates'][0]['incumbent'] == True
    #incumbent = 'R'
#elif mt[2]['estimates'][0]['incumbent'] == True
    #incumbent = 'D'
#mt[2]['estimates'][0]['incumbent']


#mt[3]['estimates'][]['last_name']
#mt[3]['estimates'][1]
#len(mt[3]['estimates'][1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-460-d31f2714074e> in <module>()
#       8 for r in range(races):
#       9     states = (mt[r]['state'])
# ---> 10     if mt[r]['estimates'][0]['party'] == 'Rep':
#      11             R = (mt[r]['estimates'][0]['choice'])
#      12             D = (mt[r]['estimates'][1]['choice'])
#
# IndexError: list index out of range

# %% [markdown]
# ## Problem 2: Confidence Intervals
#
# Compute a 99% confidence interval for each state.

# %% [markdown]
# #### Problem 2(a)
#
# Assume you have $M$ polls with sample sizes $n_1, \dots, n_M$. If the polls are independent, what is the average of the variances of each poll if the true proportion is $p$?

# %%
#[n * p * (1-p)]

# %% [markdown]
# ** Your answer here: **

# %% [markdown]
# #### Problem 2(b)
#
# Compute the square root of these values in Problem 2(a) for the republican candidates in each race. Then, compute the standard deviations of the observed poll results for each race.

# %%
#The proportion formula is for the variance. The square root of the variance is the standard deviation.

# %% [markdown]
# #### Problem 2(c)
#
# Plot observed versus theoretical (average of the theoretical SDs) with the area of the point proportional to number of polls. How do these compare?

# %%
### Your code here ###

# %% [markdown]
# ** Your answer here: **

# %% [markdown]
# #### Problem 2(d)
#
# Repeat Problem 2(c) but include only the most recent polls from the last two months. Do they match better or worse or the same? Can we just trust the theoretical values?

# %%
### Your code here ###

# %% [markdown]
# ** Your answer here: **

# %% [markdown]
# #### Problem 2(e)
#
# Create a scatter plot with each point representing one state. Is there one or more races that are outlier in that it they have much larger variabilityes than expected ? Explore the original poll data and explain why the discrepancy?

# %%
### Your code here ###

# %% [markdown]
# ** Your answer here: **

# %% [markdown]
# #### Problem 2(f)
#
#  Construct confidence intervals for the difference in each race. Use either theoretical or data driven estimates of the standard error depending on your answer to this question. Use the results in Problem 2(e), to justify your choice.

# %%
### Your code here ###

# %% [markdown]
# # Problem 3: Prediction and Posterior Probabilities
#
# Perform a Bayesian analysis to predict the probability of Republicans winning in each state then provide a posterior distribution of the number of republicans in the senate.

# %% [markdown]
# #### Problem 3(a)
#
# First, we define a Bayesian model for each race. The prior for the difference $d$ between republicans and democtrats will be $N(\mu,\tau^2)$. Say before seeing poll data you have idea who is going to win, what should $\mu$ be? How about $\tau$, should it be large or small?

# %% [markdown]
# ** Your answer here: **

# %% [markdown]
# #### Problem 3(b)
#
# What is the distribution of $d$ conditioned on $\mu$. What is the posterior distribution of $\mu | d$?
#
# **Hint**: Use normal approximation.

# %% [markdown]
# **Your answer here:**

# %% [markdown]
# #### Problem 3(c)
#
# The prior represents what we think before hand. We do not know who is expected to win, so we assume $\mu=0$. For this problem estimate $\tau$ using the observed differences across states (Hint: $\tau$ represents the standard deviation of a typical difference). Compute the posterior mean for each state and plot it against original average. Is there much change? Why or why not?

# %%
### Your code here ###

# %% [markdown]
# **Your answer here:**

# %% [markdown]
# #### Problem 3(d)
#
# For each state, report a probabilty of Republicans winning. How does your answer here compare to the other aggregators?

# %%
### Your code here ###

# %% [markdown]
# **Your answer here:**

# %% [markdown]
# #### Problem 3(e)
#
# Use the posterior distributions in a Monte Carlo simulation to generate election results. In each simulation compute the total number of seats the Republican control. Show a histogram of these results.

# %%
### Your code here ###

# %% [markdown]
# ## Problem 4
#
# Predict the results for the 2014 Midterm Elections. We will have a three competitions with the terms for scoring entries described above. For both questions below, **explain** or provide commentary on how you arrived at your predictions including code.
#
# **Hint**: Use election results from 2010, 2012 to build and test models.

# %% [markdown]
# #### Problem 4(a)
#
# Predict the number of Republican senators. You may provide an interval. Smallest interval that includes the election day result wins.
#
# **Note**: we want the total so add the numbers of those that are not up for election.

# %%
### Your code here ###

# %% [markdown]
# **Provide an explanation of methodology here**:

# %% [markdown]
# #### Problem 4(b)
#
# Predict the R-D difference in each state. The predictions that minimize the residual sum of squares between predicted and observed differences wins.

# %%
### Your code here ###

# %% [markdown]
# **Provide an explanation of methodology here**:

# %% [markdown]
# #### Problem 4(c)
#
# Report a confidence interval for the R-D difference in each state. If the election day result falls outside your confidence interval in more than two states you are eliminated. For those surviving this cutoff, we will add up the size of all confidence intervals and sum. The smallest total length of confidence interval wins.
#
# **Note**: you can use Bayesian credible intervals or whatever else you want.

# %%
### Your code here ###

# %% [markdown]
# **Provide an explanation of methodology here**:

# %% [markdown]
# # Submission Instructions
#
# To submit your homework, create a folder named **lastname_firstinitial_hw#** and place your IPython notebooks, data files, and any other files in this folder. Your IPython Notebooks should be completely executed with the results visible in the notebook. We should not have to run any code.  Compress the folder (please use .zip compression) and submit to the CS109 dropbox in the appropriate folder. *If we cannot access your work because these directions are not followed correctly, we will not grade your work.*
